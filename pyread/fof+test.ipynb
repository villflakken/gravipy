# %%
import sys, os, glob, time
import numpy as N
import subprocess as sp
import pylab as pl

from mpl_toolkits.mplot3d import Axes3D
from matplotlib import rc
rc('font',**{'family':'serif'})
time_init_start = time.time()

# ==============================================
# Read.& proc. toolkit for data sets' structure.
# ==============================================
from read_usertools import UserTools

# ==============================================
# Read.& proc. data sets' visualisation tools.
# ==============================================
from read_plotdoc import Plotter

# ==============================================
# Reading toolkit for data sets' structure.
# ==============================================
from read_misctools import MiscTools

# ==============================================
# File interpreters for read.py's interface.
# ==============================================
from read_sifters import Sifters

# ==============================================
# Reading procedure for data sets' structure.
# ==============================================
from read_procedures import readProcedures

# ==============================================
# Argument interpreter for read.py's interface.
# ==============================================
from read_args import readArgs

# ==============================================
# Indra data sets' reading MO.
# ==============================================
from read import readDo

time_init_end = time.time()

print "Initialization time: {0:.2f} seconds".format((time_init_end - time_init_start))
# Out:
# Initialization time: 0.06 seconds

# %%
def read_ini( what="pos", indraN=0, iA=0, iB=0, subfolder=None, fftfile=None, 
              tmpfolder=False, sfset=False, sortIDs=False, lessprint=True,
              multiset=False,
              box_params=False,
              outputpath=False,
              w2f=False,
              plotdata=False,
              plotdim=2,
              origamipath=False
            ):

    data_params = \
        { # Data structure parameters:
               "what" :( list(what)  ),
             "indraN" :( indraN      ),
                 "iA" :( iA          ),
                 "iB" :( iB          ),
          "subfolder" :( subfolder   ),
            "fftfile" :( fftfile     ),
            # Reading options:
          "tmpfolder" :( tmpfolder   ),
              "sfset" :( sfset       ),
            "sortIDs" :( sortIDs     ),
          "lessprint" :( lessprint   ),
           "multiset" :( multiset    ),
            # Extracts data from a coordinate box at positions specified:
         "box_params" :( box_params  ),
            # Desired output filepath, 
            # or False (program storing to user's own folder).
         "outputpath" :( outputpath  ),
            # Write 2 file: Probably a bad idea ...
                "w2f" :( w2f         ),
           "plotdata" :( plotdata    ),
            # Apply floats as "([min,max], [min,max], [min,max])" in Mpc/h units,
            # respectively for directions x, y, z. # Turned off w/: None/False
            "plotdim" :( plotdim     ), # Dimensions projected in plot
            # Origami functionality
        "origamipath" :( origamipath )
        }

    tmp = sp.call('clear',shell=True)

    ini = readDo()                # Initialize!
    ini.read_params = data_params # Set params
    " 1. "
    ini.callArgsChecker()         # Verify values
    " 2. "
    return ini.beginReading(), ini     # Do the thing

# Calling function

# %%
# Read halo IDs
outputvars, fofinstance =\
    read_ini(
                what       = ["fof"], # "vel", "fof", etc 
                indraN     = 2,
                iA         = 0,
                iB         = 0,
                subfolder  = 63,
                tmpfolder  = True,
#                 multiset   = "store"
    )

Ngroups, Nids, TotNgroups, GroupLen, GroupOffset, fofIDs = outputvars
# Out:
#  Total parameters loaded: 16
#  Parameters initialized with values:
#         what : ['fof']
#       indraN :      2
#           iA :      0
#           iB :      0
#    subfolder :     63
#    tmpfolder :   True
#        sfset :  False
#      sortIDs :  False
#    lessprint :   True
#     multiset :  False
#   box_params :  False
#   outputpath :  False
#          w2f :  False
#     plotdata :  False
#      plotdim :      2
#  origamipath :  False
#
#             All necessary parameters have been set. Continuing...
#
#
#     --- --- --- --- --- --- --- --- --- --- --- --- --- --- --- ---
#         Currently reading:
#         Data type   :    fof   (/out of sets:   'fof'    )
#         indraN      :      2             ( /:    [2]     )
#         iA          :      0             ( /:    [0]     )
#         iB          :      0             ( /:    [0]     )
#         subfolder   :     63             ( /:    [63]    )
#
#  Browsing FOF-files (tabs):
#         ---------------------------------------------------------------------
#         |__i__|_NIDs____|_Ngroups_|_sum(Ngroups)_|_TotNgroups_| Completion: |
#         ---------------------------------------------------------------------
#         |   0 | 1368865 |   12146 |        12146 |    3037186 |      0.40%  |
#         ---------------------------------------------------------------------
#         |  50 | 1296710 |   12057 |       607500 |    3037186 |     20.00%  |
#         ---------------------------------------------------------------------
#         | 100 | 1347475 |   11640 |      1199243 |    3037186 |     39.49%  |
#         ---------------------------------------------------------------------
#         | 150 | 1356054 |   12239 |      1793789 |    3037186 |     59.06%  |
#         ---------------------------------------------------------------------
#         | 200 | 1437416 |   11761 |      2385262 |    3037186 |     78.54%  |
#         ---------------------------------------------------------------------
#         | 250 | 1369677 |   12333 |      2978234 |    3037186 |     98.06%  |
#         ---------------------------------------------------------------------
#         | 255 | 1321684 |   11453 |      3037186 |    3037186 |    100.00%  |
#         ---------------------------------------------------------------------
#
#  Browsing FOF-files (IDs):
# Finished reading 'fof', indra2, iA=0, iB=0, snapshot=63
#     Done with loop, now returning data.

# %%
#%tb

# %%
" Extracting halo IDs "
haloIDs = fofIDs[GroupOffset[3]:GroupOffset[3]+GroupLen[3]]

# %%
" Extract positions "
from read import read_ini
IDs, pos, scalef, rs = read_ini(
    what       = ["pos"],
    indraN     = 2,
    iA         = 0,
    iB         = 0,
    subfolder  = 63,
    tmpfolder  = True,
    sortIDs    = True
)
# Out:
#  Total parameters loaded: 16
#  Parameters initialized with values:
#         what : ['pos']
#       indraN :      2
#           iA :      0
#           iB :      0
#    subfolder :     63
#    tmpfolder :   True
#        sfset :  False
#      sortIDs :   True
#    lessprint :   True
#     multiset :  False
#   box_params :  False
#   outputpath :  False
#          w2f :  False
#     plotdata :  False
#      plotdim :      2
#  origamipath :  False
#
#             All necessary parameters have been set. Continuing...
#
#
#     --- --- --- --- --- --- --- --- --- --- --- --- --- --- --- ---
#         Currently reading:
#         Data type   :    pos   (/out of sets:   'pos'    )
#         indraN      :      2             ( /:    [2]     )
#         iA          :      0             ( /:    [0]     )
#         iB          :      0             ( /:    [0]     )
#         subfolder   :     63             ( /:    [63]    )
#
#   * Accessing file:	indra2tmp/snap63/file.0   (pos) ...
#   * Accessing file:	indra2tmp/snap63/file.50  (pos) ...
#   * Accessing file:	indra2tmp/snap63/file.100 (pos) ...
#   * Accessing file:	indra2tmp/snap63/file.150 (pos) ...
#   * Accessing file:	indra2tmp/snap63/file.200 (pos) ...
#   * Accessing file:	indra2tmp/snap63/file.250 (pos) ...
#   * Accessing file:	indra2tmp/snap63/file.255 (pos) ...
#
#     Byte sifter completed.
#     Max particle number in a file:      4435841
#     Sum particles read / Tot. in sim.:  1.07374e+09 / 1.07374e+09 ( 100% )
#     Maximum indra particles read?:      True
#     Size of array    IDsA = 8.59 GBs
#     Size of matrix   posA = 12.88 GBs
#     Size of matrix   velA = 12.88 GBs
#     Size of array  NpartA = 2.05 KBs
#     Total size of matrices IDsA, posA, velA, NpartA = 34.36 GBs
#
#     Sifter has completed reading all 256 files of snap 63.
#     - Commencing method for sorting positions and velocities.
#   * Sorting IDs now ...
#     \=> IDs sorted.
#   * Sorting positions.
#     \=> positions' array now sorted by ID tag.
# ValueErrorTraceback (most recent call last)
# <ipython-input-6-d2e273b05aff> in <module>()
#       8     subfolder  = 63,
#       9     tmpfolder  = True,
# ---> 10     sortIDs    = True
#      11 )
#
# /home/idies/workspace/persistent/gravipy_multi/pyread/read.pyc in read_ini(what, indraN, iA, iB, subfolder, fftfile, tmpfolder, sfset, sortIDs, lessprint, multiset, box_params, outputpath, w2f, plotdata, plotdim, origamipath)
#      61     ini.callArgsChecker()         # Verify values
#      62     " 2. "
# ---> 63     return ini.beginReading()     # Do the thing
#      64
#      65
#
# /home/idies/workspace/persistent/gravipy_multi/pyread/read.pyc in beginReading(self)
#     169
#     170                             " Task function call: "
# --> 171                             parsed_data = self.action[self.what]()
#     172                             " >: Main component of program. "
#     173
#
# /home/idies/workspace/persistent/gravipy_multi/pyread/read_procedures.pyc in read_posvel(self)
#     135     - Commencing method for sorting positions and velocities."""\
#     136                             .format(iterLen, self.subfolder)
# --> 137             IDsA, posA, velA = self.sort_from_IDsF(IDsA, posA, velA, self.what)
#     138             pass
#     139
#
# ValueError: need more than 2 values to unpack

# %%
import pylab as pl
" Plotting sandbox below "

# %%
pl.figure(figsize=(10,10))
pl.plot(pos[haloIDs,0],pos[haloIDs,1],'m.')
pl.xlabel('x (Mpc/h)')
pl.ylabel('y (Mpc/h)')
pl.axis('equal')
pl.xlim([22, 40])
pl.ylim([56, 70])
pl.show()
